# %% [markdown]
# <a href="https://colab.research.google.com/github/Madushani-Weerasekara/NLP_PracticeAssignment1_SelfStudy/blob/main/NLP_PracticeAssignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
#Import libraries

import pandas as pd

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
#Download the necessary NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
path_file = "/content/test.csv"

# %%
df = pd.read_csv(path_file)
df.head()
# Out:
#    test_id                       description_x  \
# 0        0                        semtech corp
# 1        1              vanguard mid cap index
# 2        2         spdr gold trust gold shares
# 3        3       vanguard total bond index adm
# 4        4  oakmark international fund class i
#
#                       description_y  same_security
# 0               semtech corporation            NaN
# 1         vanguard midcap index - a            NaN
# 2  spdr gold trust spdr gold shares            NaN
# 3  vanguard total bond market index            NaN
# 4        oakmark international cl i            NaN

# %%
# word tokenization(split sentences into words)

for index, row in df.iterrows(): # tokenize sentence within each row
  sentences = nltk.sent_tokenize(row['description_x'])
  for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    print(words)
# Out:
# ['semtech', 'corp']
# ['vanguard', 'mid', 'cap', 'index']
# ['spdr', 'gold', 'trust', 'gold', 'shares']
# ['vanguard', 'total', 'bond', 'index', 'adm']
# ['oakmark', 'international', 'fund', 'class', 'i']
# ['pfizer', 'inc', 'div', ':', '1.200']
# ['spartan', 'global', 'ex', 'us', 'index', 'fid', 'adv', 'cl']
# ['vanguard', 'total', 'bond', 'market', 'idx-adm']
# ['banco', 'latinoamericano', 'de', 'exportacio', 'class', 'e', 'com', 'stk', 'npv']
# ['baidu', 'inc', 'fadr', '1', 'adr', 'reps', '0.1', 'ord', 'shs']
# ['whole', 'foods', 'market']
# ['walgreens', 'boots', 'alliance', 'inc', 'com']
# ['diageo', 'plc', 'new', 'gb', 'spon', 'adr']
# ['guggenheim', 'bulletshares', '2016']
# ['vanguard', 'small-cap', 'index', 'adm']
# ['emerging', 'markets']
# ['spdr', 's', '&', 'p', '500', 'etf', 'iv']
# ['tegna', 'inc', 'com']
# ['deere', '&', 'company']
# ['vanguard', 'mid-cap', 'index']
# ['jpmorgan', 'chase', '&', 'co', 'div', ':', '1.760']
# ...

# %%
# Define the function for tokenization
def tokenize_text(description_x):
  return word_tokenize(description_x)

# %%
# Aplly tokenization to the description_x column
df['tokenized_text'] = df['description_x'].apply(tokenize_text)

# %%
# Display the DataFrame with tokenized_text column
print(df[['description_x', 'tokenized_text']].head())
# Out:
#                         description_x  \
# 0                        semtech corp
# 1              vanguard mid cap index
# 2         spdr gold trust gold shares
# 3       vanguard total bond index adm
# 4  oakmark international fund class i
#
#                              tokenized_text
# 0                           [semtech, corp]
# 1               [vanguard, mid, cap, index]
# 2         [spdr, gold, trust, gold, shares]
# 3       [vanguard, total, bond, index, adm]
# 4  [oakmark, international, fund, class, i]

# %%
df
# Out:
#      test_id                                   description_x  \
# 0          0                                    semtech corp
# 1          1                          vanguard mid cap index
# 2          2                     spdr gold trust gold shares
# 3          3                   vanguard total bond index adm
# 4          4              oakmark international fund class i
# ..       ...                                             ...
# 511      511  at&t inc com isin #us00206r1023 sedol #2831811
# 512      512     vanguard total international bond index etf
# 513      513                wisdomtree japan hedged equity -
# 514      514        templeton global bond fund advisor class
# 515      515                             trp health sciences
#
#                                      description_y  same_security  \
# 0                              semtech corporation            NaN
# 1                        vanguard midcap index - a            NaN
# ...

# %%
# Apply Stemming
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))
for i in range(len(sentences)):
  for word in words:
    if word not in set(stopwords.words('english')):
      stemmed_words = [stemmer.stem(word) for wor in words if word not in stop_words]
      print(stemmed_words)
# Out:
# ['trp', 'trp', 'trp']
# ['health', 'health', 'health']
# ['scienc', 'scienc', 'scienc']

# %%
# Apply Lemmatization

def lemmatize_text(description_x):
  tokens = word_tokenize(description_x)
  lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]

# %%
# Apply lemmatization to the description_x column
lemmatizer = WordNetLemmatizer()
df['lemmatized_text'] = df['description_x'].apply(lemmatize_text)

# %%
# Display dataFrame with the lemmatize_text column

print(df[['description_x', 'lemmatized_text']].head())
# Out:
#                         description_x lemmatized_text
# 0                        semtech corp            None
# 1              vanguard mid cap index            None
# 2         spdr gold trust gold shares            None
# 3       vanguard total bond index adm            None
# 4  oakmark international fund class i            None
